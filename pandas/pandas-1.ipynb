# %%
import pandas as pd
import IPython
import numpy as np
import matplotlib.pyplot as plt

# %%
#pd.set_option('display.notebook_repr_html', True)
# Series
s = pd.Series([2,4,8,6,4],index=['a','b','c','d','e'])
print(s)
# Out:
# a    2
# b    4
# c    8
# d    6
# e    4
# dtype: int64

# %%
# dataframe
data = {'Country' : ['india','france','england'],
       'capital' : ['New delhi','Paris','London'],
       'Population' : [1303131035,111908046,204565786]}
df = pd.DataFrame(data,columns=['Country','capital','Population'])

print(df)
display(df)
# Out:
#    Country    capital  Population
# 0    india  New delhi  1303131035
# 1   france      Paris   111908046
# 2  england     London   204565786
#    Country    capital  Population
# 0    india  New delhi  1303131035
# 1   france      Paris   111908046
# 2  england     London   204565786

# %%
# I/O

# read and write csv
df.to_csv('country.csv',index=None)
df1 = pd.read_csv('country.csv')
display(df1)
df11 = df

# read and write from excel
df.to_excel('country.xlsx',sheet_name='country')
df2 = pd.read_excel('country.xlsx',sheetname='country')
display(df2)
# Out:
#    Country    capital  Population
# 0    india  New delhi  1303131035
# 1   france      Paris   111908046
# 2  england     London   204565786
#    Country    Capital  Population
# 0    india  New dehli   134212015
# 1   france      Paris   111908046
# 2  england     landon   204565789

# %%
# Selection

# getting
display(s)
print(s['b'])

display(df)
display(df[:1])                    # :1 print everything before 1--- 1: print everything after 1

# by position
print(df.iloc[0,0],'\n')                     
print(df.iat[2,0],'\n')

# by label 
print(df.loc[0,'Country'],'\n')
print(df.at[1,'Country'],'\n')

print(df.ix[2],'\n')
print(df.ix[:,'capital'],'\n')
print(df.ix[1,'capital'],'\n')

# boolean indexing
print(s[~(s>3)],'\n')
print(s[(s<-1) | (s>2)],'\n')

# setting
s['a'] = 6
print(s)
# Out:
# a    2
# b    4
# c    8
# d    6
# e    4
# dtype: int64
# 4
#    Country    capital  Population
# 0    india  New delhi  1303131035
# 1   france      Paris   111908046
# 2  england     London   204565786
#   Country    capital  Population
# 0   india  New delhi  1303131035
# india
#
# england
#
# india
#
# france
#
# Country         england
# capital          London
# Population    204565786
# Name: 2, dtype: object
#
# 0    New delhi
# 1        Paris
# 2       London
# Name: capital, dtype: object
#
# Paris
#
# a    2
# dtype: int64
#
# b    4
# c    8
# d    6
# e    4
# dtype: int64
#
# a    6
# b    4
# c    8
# d    6
# e    4
# dtype: int64
# c:\users\zero\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:18: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix

# %%
# Dropping
display(s)                                          #not working
s.drop('a',axis=0)
display(s)

display(df)
df.drop('Country',axis=1)
# Out:
# a    6
# b    4
# c    8
# d    6
# e    4
# dtype: int64
# a    6
# b    4
# c    8
# d    6
# e    4
# dtype: int64
#    Country    capital  Population
# 0    india  New delhi  1303131035
# 1   france      Paris   111908046
# 2  england     London   204565786
#      capital  Population
# 0  New delhi  1303131035
# 1      Paris   111908046
# 2     London   204565786

# %%
# sort and rank
display(df.sort_index())
display(df.sort_values(by='Country'))
print(df.rank)
# Out:
#    Country    capital  Population
# 0    india  New delhi  1303131035
# 1   france      Paris   111908046
# 2  england     London   204565786
#    Country    capital  Population
# 2  england     London   204565786
# 1   france      Paris   111908046
# 0    india  New delhi  1303131035
# <bound method NDFrame.rank of    Country    capital  Population
# 0    india  New delhi  1303131035
# 1   france      Paris   111908046
# 2  england     London   204565786>

# %%
# Data frame information

# basic information
print(df.shape,' = shape\n')
print(df.index,' = index\n')
print(df.columns,' = coloumns\n')
print(df.info(),' = info\n')
print(df.count(),' = count\n')

# Summary
print(df.sum(),' = sum of values\n')
print(df.cumsum(),' = cummulative sum of values\n')
print(df.min(),' = min\n')
print(df.max(),' = max\n')
#print(df.idxmin(),' = min index value\n')                                    # not working
#print(df.idxmax(),' = max index value\n')
print(df.describe(),' = describe\n')
print(df.mean(),' = mean\n')
print(df.median(),' = median\n')
# Out:
# (3, 3)  = shape
#
# RangeIndex(start=0, stop=3, step=1)  = index
#
# Index(['Country', 'capital', 'Population'], dtype='object')  = coloumns
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
# Country       3 non-null object
# capital       3 non-null object
# Population    3 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 152.0+ bytes
# None  = info
#
# Country       3
# capital       3
# Population    3
# dtype: int64  = count
#
# Country         indiafranceengland
# capital       New delhiParisLondon
# Population              1619604867
# dtype: object  = sum of values
#
#               Country               capital  Population
# 0               india             New delhi  1303131035
# 1         indiafrance        New delhiParis  1415039081
# 2  indiafranceengland  New delhiParisLondon  1619604867  = cummulative sum of values
#
# Country         england
# capital          London
# Population    111908046
# ...

# %%
# applying functions

f = lambda x: x*2
display(df.apply(f))
display(df.applymap(f))
# Out:
#           Country             capital  Population
# 0      indiaindia  New delhiNew delhi  2606262070
# 1    francefrance          ParisParis   223816092
# 2  englandengland        LondonLondon   409131572
#           Country             capital  Population
# 0      indiaindia  New delhiNew delhi  2606262070
# 1    francefrance          ParisParis   223816092
# 2  englandengland        LondonLondon   409131572

# %%
# data allignment
s3 = pd.Series([9,2,5],index=['a','c','d'])
display(s3)
s3 = s + s3
display(s3)
display(s)

display(s.add(s3,fill_value=0))
print(s.sub(s3,fill_value=2),' = sub\n')
print(s.div(s3,fill_value=4),' = div\n')
# Out:
# a    9
# c    2
# d    5
# dtype: int64
# a    15.0
# b     NaN
# c    10.0
# d    11.0
# e     NaN
# dtype: float64
# a    6
# b    4
# c    8
# d    6
# e    4
# dtype: int64
# a    21.0
# b     4.0
# c    18.0
# d    17.0
# e     4.0
# dtype: float64
# a   -9.0
# b    2.0
# c   -2.0
# d   -5.0
# e    2.0
# dtype: float64  = sub
#
# a    0.400000
# b    1.000000
# c    0.800000
# d    0.545455
# e    1.000000
# dtype: float64  = div

# %%
# Reshape Data

data = {'date' : ['2017-04-01','2017-06-01','2017-03-01','2017-05-01','2017-03-01','2017-04-08'],
       'type' : ['a','b','c','a','a','b'],
       'value' : [11.32,65.32,45.26,85,65.12,13]}
df2 = pd.DataFrame(data)
display(df)
df22 = df2

# pivote
df3 = df2.pivot(columns='type',index='date',values='value')

display(df3)
# Out:
#    Country    capital  Population
# 0    india  New delhi  1303131035
# 1   france      Paris   111908046
# 2  england     London   204565786
# type            a      b      c
# date
# 2017-03-01  65.12    NaN  45.26
# 2017-04-01  11.32    NaN    NaN
# 2017-04-08    NaN  13.00    NaN
# 2017-05-01  85.00    NaN    NaN
# 2017-06-01    NaN  65.32    NaN

# %%
# pivot table
df4 = pd.pivot_table(df2,columns='type',values='value',index='date')
display(df4)
# Out:
# type            a      b      c
# date
# 2017-03-01  65.12    NaN  45.26
# 2017-04-01  11.32    NaN    NaN
# 2017-04-08    NaN  13.00    NaN
# 2017-05-01  85.00    NaN    NaN
# 2017-06-01    NaN  65.32    NaN

# %%
# stacking

stacked = df3.stack()
display(stacked)
stacked.unstack()
# Out:
# date        type
# 2017-03-01  a       65.12
#             c       45.26
# 2017-04-01  a       11.32
# 2017-04-08  b       13.00
# 2017-05-01  a       85.00
# 2017-06-01  b       65.32
# dtype: float64
# type            a      b      c
# date
# 2017-03-01  65.12    NaN  45.26
# 2017-04-01  11.32    NaN    NaN
# 2017-04-08    NaN  13.00    NaN
# 2017-05-01  85.00    NaN    NaN
# 2017-06-01    NaN  65.32    NaN

# %%
# melt
display(df2)
print('\n')
display(pd.melt(df2,id_vars=['date'],value_vars=['type','value'],value_name='observations'))
# Out:
#          date type  value
# 0  2017-04-01    a  11.32
# 1  2017-06-01    b  65.32
# 2  2017-03-01    c  45.26
# 3  2017-05-01    a  85.00
# 4  2017-03-01    a  65.12
# 5  2017-04-08    b  13.00
#           date variable observations
# 0   2017-04-01     type            a
# 1   2017-06-01     type            b
# 2   2017-03-01     type            c
# 3   2017-05-01     type            a
# 4   2017-03-01     type            a
# 5   2017-04-08     type            b
# 6   2017-04-01    value        11.32
# 7   2017-06-01    value        65.32
# 8   2017-03-01    value        45.26
# 9   2017-05-01    value           85
# 10  2017-03-01    value        65.12
# 11  2017-04-08    value           13

# %%
# iteration

df.iteritems()
df.iterrows()                                      # understand
# Out:
# <generator object DataFrame.iterrows at 0x000001D07DF33B48>

# %%
# advanced indexing

# selecting
display(df3)
display(df3.loc[:,(df3>1).any()])
display(df3.loc[:,(df3>1).all()])
display(df3.loc[:,df3.isnull().any()])
display(df3.loc[:,df3.notnull().all()])

# indexing with isin
display(df)
display(df[df.Country.isin(df2.type)])
display(df.filter(items=["a","b"]))
display(df.select(lambda x: not x%5))

# where
display(s.where(s>4))

# query
df.query('0')                                           # verify
# Out:
# type            a      b      c
# date
# 2017-03-01  65.12    NaN  45.26
# 2017-04-01  11.32    NaN    NaN
# 2017-04-08    NaN  13.00    NaN
# 2017-05-01  85.00    NaN    NaN
# 2017-06-01    NaN  65.32    NaN
# type            a      b      c
# date
# 2017-03-01  65.12    NaN  45.26
# 2017-04-01  11.32    NaN    NaN
# 2017-04-08    NaN  13.00    NaN
# 2017-05-01  85.00    NaN    NaN
# 2017-06-01    NaN  65.32    NaN
# Empty DataFrame
# Columns: []
# Index: [2017-03-01, 2017-04-01, 2017-04-08, 2017-05-01, 2017-06-01]
# type            a      b      c
# date
# 2017-03-01  65.12    NaN  45.26
# 2017-04-01  11.32    NaN    NaN
# 2017-04-08    NaN  13.00    NaN
# 2017-05-01  85.00    NaN    NaN
# 2017-06-01    NaN  65.32    NaN
# Empty DataFrame
# Columns: []
# Index: [2017-03-01, 2017-04-01, 2017-04-08, 2017-05-01, 2017-06-01]
#    Country    capital  Population
# 0    india  New delhi  1303131035
# 1   france      Paris   111908046
# 2  england     London   204565786
# Empty DataFrame
# ...

# %%
# Setting / reseting
display(df)
display(df.set_index('Country'))
df4 = df.reset_index()
display(df4)
df = df.rename(index=str,columns={'Country':'cntry',
                                 'capital':'cptl',
                                 'Population':'ppltn'})
display(df)
# Out:
#    Country    capital  Population
# 0    india  New delhi  1303131035
# 1   france      Paris   111908046
# 2  england     London   204565786
#            capital  Population
# Country
# india    New delhi  1303131035
# france       Paris   111908046
# england     London   204565786
#    index  Country    capital  Population
# 0      0    india  New delhi  1303131035
# 1      1   france      Paris   111908046
# 2      2  england     London   204565786
#      cntry       cptl       ppltn
# 0    india  New delhi  1303131035
# 1   france      Paris   111908046
# 2  england     London   204565786

# %%
# reindexing

display(s)
s2 = s.reindex(['e','c','g','f','a'])
display(s2)

# forward filling
df = df11
display(df)
#df.reindex(range(4),method='ffill')

# backward fill
#s3 = s.reindex(range(5),method='bfill')                  # check

# multi indexing

arrays = [np.array([1,2,3]),
         np.array([5,6,7])]

df5 = pd.DataFrame(np.random.rand(3,2),index=arrays)
display(df5)

tuples = list(zip(*arrays))
index = pd.MultiIndex.from_tuples(tuples,names=('first','second'))
df6 = pd.DataFrame(np.random.rand(3,2),index=index)
display(df6)
df2.set_index(['cntry','cptl'])
# Out:
# a    6
# b    4
# c    8
# d    6
# e    4
# dtype: int64
# e    4.0
# c    8.0
# g    NaN
# f    NaN
# a    6.0
# dtype: float64
#    Country    capital  Population
# 0    india  New delhi  1303131035
# 1   france      Paris   111908046
# 2  england     London   204565786
#             0         1
# 1 5  0.712295  0.468063
# 2 6  0.114091  0.175052
# 3 7  0.414663  0.476721
#                      0         1
# first second
# 1     5       0.997394  0.770307
# 2     6       0.971890  0.670511
# 3     7       0.656817  0.387930
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\zero\appdata\local\programs\python\python35\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# ...

# %%
# duplicate data
print(s3.unique())
display(df2)
display(df2.duplicated('cntry'))
display(df2.drop_duplicates('cntry',keep='last'))
df2.index.duplicated()
# Out:
# [ 15.  nan  10.  11.]
#          date type  value
# 0  2017-04-01    a  11.32
# 1  2017-06-01    b  65.32
# 2  2017-03-01    c  45.26
# 3  2017-05-01    a  85.00
# 4  2017-03-01    a  65.12
# 5  2017-04-08    b  13.00
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\zero\appdata\local\programs\python\python35\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5280)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5126)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20523)()
#
# ...

# %%
# grouping data
display(df2)
display(df2.groupby(by=['cntry','cptl']).mean())
display(df4)
display(df4.groupby(level=0).sum())
#display(df4.groupby(level=0).agg({'a': lambda x:sum(x)/len(x),'b': np.sum}))

# transformation
customSum = lambda x: (x+x%2)
display(df4.groupby(level=0).transform(customSum))
# Out:
#          date type  value
# 0  2017-04-01    a  11.32
# 1  2017-06-01    b  65.32
# 2  2017-03-01    c  45.26
# 3  2017-05-01    a  85.00
# 4  2017-03-01    a  65.12
# 5  2017-04-08    b  13.00
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-9cf79e805f52> in <module>()
#       1 # grouping data
#       2 display(df2)
# ----> 3 display(df2.groupby(by=['cntry','cptl']).mean())
#       4 display(df4)
#       5 display(df4.groupby(level=0).sum())
#
# c:\users\zero\appdata\local\programs\python\python35\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    4414         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    4415                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 4416                        **kwargs)
#    4417
# ...

# %%
# missing data
display(s3)
s3.dropna()                                          # not working
display(s3)
display(s3.fillna(s3.mean()))
display(s4 =s3.replace("b","a"))                     # not working
# Out:
# a    15.0
# b     NaN
# c    10.0
# d    11.0
# e     NaN
# dtype: float64
# a    15.0
# b     NaN
# c    10.0
# d    11.0
# e     NaN
# dtype: float64
# a    15.0
# b    12.0
# c    10.0
# d    11.0
# e    12.0
# dtype: float64

# %%
# combining data 
X = {'X1': ['a','b','c'],
        'X2' : [12,43,22]}
data1 = pd.DataFrame(X,columns=['X1','X2'])
display(data1)
X2 = {'X1': ['a','b','d'],
        'X3' : [22,23,72]}
data2 = pd.DataFrame(X2,columns=['X1','X3'])
display(data2)

display(pd.merge(data1,data2,how='right',on='X1'))
display(pd.merge(data1,data2,how='left',on='X1'))
display(pd.merge(data1,data2,how='inner',on='X1'))
display(pd.merge(data1,data2,how='outer',on='X1'))
# Out:
#   X1  X2
# 0  a  12
# 1  b  43
# 2  c  22
#   X1  X3
# 0  a  22
# 1  b  23
# 2  d  72
#   X1    X2  X3
# 0  a  12.0  22
# 1  b  43.0  23
# 2  d   NaN  72
#   X1  X2    X3
# 0  a  12  22.0
# 1  b  43  23.0
# 2  c  22   NaN
#   X1  X2  X3
# 0  a  12  22
# 1  b  43  23
#   X1    X2    X3
# 0  a  12.0  22.0
# 1  b  43.0  23.0
# 2  c  22.0   NaN
# 3  d   NaN  72.0

# %%
# joining
display(data1.join(data2,lsuffix='X1'))             #check
pd.concat([data1,data2],axis=1,join='inner')
# Out:
#   X1X1  X2 X1  X3
# 0    a  12  a  22
# 1    b  43  b  23
# 2    c  22  d  72
#   X1  X2 X1  X3
# 0  a  12  a  22
# 1  b  43  b  23
# 2  c  22  d  72

# %%
# concatenate
display(s)
display(s2)
display(s.append(s2))
# Out:
# a    6
# b    4
# c    8
# d    6
# e    4
# dtype: int64
# e    4.0
# c    8.0
# g    NaN
# f    NaN
# a    6.0
# dtype: float64
# a    6.0
# b    4.0
# c    8.0
# d    6.0
# e    4.0
# e    4.0
# c    8.0
# g    NaN
# f    NaN
# a    6.0
# dtype: float64

# %%
# visualization
display(s)
s.plot()
plt.show()

display(df2)
df2.plot()
plt.show()
# Out:
# a    6
# b    4
# c    8
# d    6
# e    4
# dtype: int64
#          date type  value
# 0  2017-04-01    a  11.32
# 1  2017-06-01    b  65.32
# 2  2017-03-01    c  45.26
# 3  2017-05-01    a  85.00
# 4  2017-03-01    a  65.12
# 5  2017-04-08    b  13.00

# %%
display(df22)
# Out:
#         date type  value
# 0 2017-01-31    a  11.32
# 1 2017-02-28    b  65.32
# 2 2017-03-31    c  45.26
# 3 2017-04-30    a  85.00
# 4 2017-05-31    a  65.12
# 5 2017-06-30    b  13.00

# %%
# dates
df22['date'] = pd.to_datetime(df22['date'])
df22['date'] = pd.date_range('2017-1-1',periods=6,freq='M')
#dates = [datetime(2012,5,1),datetime(2012,5,2)]
index = pd.DatetimeIndex((2012,1,2))

# %%
# visualization

display('s',s)                          # display s
s.plot()                                # plot s
plt.show()                              # display graph

display('\ndf3',df3)                    # display df3
df3.plot()                              # plot df3
plt.show()                              # display graph
# Out:
#         date type  value
# 0 2017-01-31    a  11.32
# 1 2017-02-28    b  65.32
# 2 2017-03-31    c  45.26
# 3 2017-04-30    a  85.00
# 4 2017-05-31    a  65.12
# 5 2017-06-30    b  13.00
